# %%
import pandas as pd
import scanpy as sc
import argparse
import anndata as ad

# %%
parser = argparse.ArgumentParser(description='kb out directory')
parser.add_argument('--directory', '-d', default= None,required = True,  help='kb out directory')
args = parser.parse_args()
kb_path = args.directory
# Out:
# usage: ipykernel_launcher.py [-h] --directory DIRECTORY
# ipykernel_launcher.py: error: the following arguments are required: --directory/-d
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /opt/apps/python/3.10.2/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3587: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
kb_path = "/share/crsp/lab/seyedam/weberrl/IGVF_allele_specific_expression/Allele_specific_expression_pipeline/pipeline_test/work/55/2c991400834f533bf027edd0146725/sp1"

# %%
cunfmod = kb_path + '/counts_unfiltered_modified/

# %%
cunfmod
# Out:
# '/share/crsp/lab/seyedam/weberrl/IGVF_allele_specific_expression/Allele_specific_expression_pipeline/pipeline_test/work/55/2c991400834f533bf027edd0146725/sp1/counts_unfiltered_modified/'

# %%
adata = make_adata(cunfmod)
adata.layers['raw_counts'] = adata.X
# Out:
# /home/jovyan/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/jovyan/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
adata.obs
# Out:
#                                                 bc
# bc
# AAACATCGACAGCAGAACACCTTT  AAACATCGACAGCAGAACACCTTT
# AAACATCGCATACCAAGACCTTTC  AAACATCGCATACCAAGACCTTTC
# AAACATCGGCGAGTAAATGCCCTT  AAACATCGGCGAGTAAATGCCCTT
# AAACATCGTGGTGGTACCCTTATA  AAACATCGTGGTGGTACCCTTATA
# AACAACCAACATTGGCACTTGCCT  AACAACCAACATTGGCACTTGCCT
# ...                                            ...
# TGGAACAATGGAACAACCTGTTGC  TGGAACAATGGAACAACCTGTTGC
# TGGCTTCAAGTGGTCACCCTTATA  TGGCTTCAAGTGGTCACCCTTATA
# TGGCTTCACAACCACACATACTTC  TGGCTTCACAACCACACATACTTC
# TGGCTTCACTGAGCCAACACCTTT  TGGCTTCACTGAGCCAACACCTTT
# TGGTGGTACAGCGTTAACTGGCTT  TGGTGGTACAGCGTTAACTGGCTT
#
# [237 rows x 1 columns]

# %%
adata.write_h5ad('total_adata.h5ad')
